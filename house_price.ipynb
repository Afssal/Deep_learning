# %%
import pandas as pd
import tensorflow as tf
from tensorflow import keras
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

# %%
train_df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
test_df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
train_df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
for col in train_df.columns:
    if train_df[col].isnull().sum() > 100:
        print(f'{col} - {train_df[col].isnull().sum()}')
        train_df = train_df.drop(col,axis=1)
        test_df = test_df.drop(col,axis=1)
    elif train_df[col].isnull().sum() <= 100 and train_df[col].isnull().sum() > 0 and train_df[col].dtype!='object':
        train_df[col] = train_df[col].fillna(train_df[col].mean())
        test_df[col] = test_df[col].fillna(test_df[col].mean())
    elif train_df[col].isnull().sum() <= 100 and train_df[col].isnull().sum() > 0 and train_df[col].dtype =='object':
        train_df = train_df.drop(col,axis=1)
        test_df = test_df.drop(col,axis=1)
# Out:
# LotFrontage - 259
# Alley - 1369
# MasVnrType - 872
# FireplaceQu - 690
# PoolQC - 1453
# Fence - 1179
# MiscFeature - 1406

# %%
train_df
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 0        1          60       RL     8450   Pave      Reg         Lvl
# 1        2          20       RL     9600   Pave      Reg         Lvl
# 2        3          60       RL    11250   Pave      IR1         Lvl
# 3        4          70       RL     9550   Pave      IR1         Lvl
# 4        5          60       RL    14260   Pave      IR1         Lvl
# ...    ...         ...      ...      ...    ...      ...         ...
# 1455  1456          60       RL     7917   Pave      Reg         Lvl
# 1456  1457          20       RL    13175   Pave      Reg         Lvl
# 1457  1458          70       RL     9042   Pave      Reg         Lvl
# 1458  1459          20       RL     9717   Pave      Reg         Lvl
# 1459  1460          20       RL     9937   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
train_df.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotArea          0
# Street           0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 64, dtype: int64

# %%
test_df
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 0     1461          20       RH    11622   Pave      Reg         Lvl
# 1     1462          20       RL    14267   Pave      IR1         Lvl
# 2     1463          60       RL    13830   Pave      IR1         Lvl
# 3     1464          60       RL     9978   Pave      IR1         Lvl
# 4     1465         120       RL     5005   Pave      IR1         HLS
# ...    ...         ...      ...      ...    ...      ...         ...
# 1454  2915         160       RM     1936   Pave      Reg         Lvl
# 1455  2916         160       RM     1894   Pave      Reg         Lvl
# 1456  2917          20       RL    20000   Pave      Reg         Lvl
# 1457  2918          85       RL    10441   Pave      Reg         Lvl
# 1458  2919          60       RL     9627   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# ...

# %%
le = LabelEncoder()

# %%
for col in train_df.columns:
    if train_df[col].dtype=='object':
        train_df[col] = le.fit_transform(train_df[col])
        test_df[col] = le.fit_transform(test_df[col])

# %%
train_df
# Out:
#         Id  MSSubClass  MSZoning  LotArea  Street  LotShape  LandContour  \
# 0        1          60         3     8450       1         3            3
# 1        2          20         3     9600       1         3            3
# 2        3          60         3    11250       1         0            3
# 3        4          70         3     9550       1         0            3
# 4        5          60         3    14260       1         0            3
# ...    ...         ...       ...      ...     ...       ...          ...
# 1455  1456          60         3     7917       1         3            3
# 1456  1457          20         3    13175       1         3            3
# 1457  1458          70         3     9042       1         3            3
# 1458  1459          20         3     9717       1         3            3
# 1459  1460          20         3     9937       1         3            3
#
#       Utilities  LotConfig  LandSlope  ...  EnclosedPorch  3SsnPorch  \
# ...

# %%
train_df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotArea', 'Street', 'LotShape',
#        'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood',
#        'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl',
#        'Exterior1st', 'Exterior2nd', 'MasVnrArea', 'ExterQual', 'ExterCond',
#        'Foundation', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#        'Heating', 'HeatingQC', 'CentralAir', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'GarageYrBlt', 'GarageCars',
#        'GarageArea', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'SalePrice'],
# ...

# %%
train_x = train_df[['MSSubClass', 'MSZoning', 'LotArea', 'Street', 'LotShape',
       'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood',
       'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual',
       'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl',
       'Exterior1st', 'Exterior2nd', 'MasVnrArea', 'ExterQual', 'ExterCond',
       'Foundation', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
       'Heating', 'HeatingQC', 'CentralAir', '1stFlrSF', '2ndFlrSF',
       'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
       'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
       'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'GarageYrBlt', 'GarageCars',
       'GarageArea', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
       'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
       'MoSold', 'YrSold', 'SaleType', 'SaleCondition']]

# %%
train_y = train_df['SalePrice']

# %%
test_x = test_df[['MSSubClass', 'MSZoning', 'LotArea', 'Street', 'LotShape',
       'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood',
       'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual',
       'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl',
       'Exterior1st', 'Exterior2nd', 'MasVnrArea', 'ExterQual', 'ExterCond',
       'Foundation', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
       'Heating', 'HeatingQC', 'CentralAir', '1stFlrSF', '2ndFlrSF',
       'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
       'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
       'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'GarageYrBlt', 'GarageCars',
       'GarageArea', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
       'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
       'MoSold', 'YrSold', 'SaleType', 'SaleCondition']]

# %%
train_x
# Out:
#       MSSubClass  MSZoning  LotArea  Street  LotShape  LandContour  Utilities  \
# 0             60         3     8450       1         3            3          0
# 1             20         3     9600       1         3            3          0
# 2             60         3    11250       1         0            3          0
# 3             70         3     9550       1         0            3          0
# 4             60         3    14260       1         0            3          0
# ...          ...       ...      ...     ...       ...          ...        ...
# 1455          60         3     7917       1         3            3          0
# 1456          20         3    13175       1         3            3          0
# 1457          70         3     9042       1         3            3          0
# 1458          20         3     9717       1         3            3          0
# 1459          20         3     9937       1         3            3          0
#
# ...

# %%
train_y.isnull().sum()
# Out:
# 0

# %%
test_x.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotArea          0
# Street           0
# LotShape         0
#                 ..
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# Length: 62, dtype: int64

# %%
test_x.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotArea          0
# Street           0
# LotShape         0
#                 ..
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# Length: 62, dtype: int64

# %%
train_x_ = (train_x-train_x.mean())/train_x.std()

# %%
train_x_
# Out:
#       MSSubClass  MSZoning   LotArea    Street  LotShape  LandContour  \
# 0       0.073350 -0.045516 -0.207071  0.064216  0.750473     0.314559
# 1      -0.872264 -0.045516 -0.091855  0.064216  0.750473     0.314559
# 2       0.073350 -0.045516  0.073455  0.064216 -1.378460     0.314559
# 3       0.309753 -0.045516 -0.096864  0.064216 -1.378460     0.314559
# 4       0.073350 -0.045516  0.375020  0.064216 -1.378460     0.314559
# ...          ...       ...       ...       ...       ...          ...
# 1455    0.073350 -0.045516 -0.260471  0.064216  0.750473     0.314559
# 1456   -0.872264 -0.045516  0.266316  0.064216  0.750473     0.314559
# 1457    0.309753 -0.045516 -0.147760  0.064216  0.750473     0.314559
# 1458   -0.872264 -0.045516 -0.080133  0.064216  0.750473     0.314559
# 1459   -0.872264 -0.045516 -0.058092  0.064216  0.750473     0.314559
#
#       Utilities  LotConfig  LandSlope  Neighborhood  ...  OpenPorchSF  \
# ...

# %%
shp = train_x_.shape[1]

# %%
shp
# Out:
# 62

# %%
# train_x_ = scaled_train_x.to_numpy()
# train_y_ = train_y.to_numpy()
# test_x_ = scaled_test_x.to_numpy()

# %%
model = tf.keras.Sequential(
    [keras.layers.Dense(50, activation='relu',input_shape = (shp,)),
     keras.layers.Dense(50,activation='relu'),
     keras.layers.Dense(1)]
)
# Out:
# e:\github\deeplearning\env\Lib\site-packages\keras\src\layers\core\dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam',loss='mean_squared_error')

# %%
model.fit(train_x_,train_y,epochs=500)
# Out:
# Epoch 1/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 38826991616.0000
# Epoch 2/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 40892932096.0000
# Epoch 3/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 39063834624.0000
# Epoch 4/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 37481218048.0000
# Epoch 5/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 39574257664.0000
# Epoch 6/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 38740729856.0000
# Epoch 7/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 36816154624.0000
# Epoch 8/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 38086500352.0000
# Epoch 9/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 36877078528.0000
# Epoch 10/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 36417478656.0000
# Epoch 11/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 34909163520.0000
# Epoch 12/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 35490803712.0000
# Epoch 13/500
# ...
